# %%
"""Implementation of Clonal selection algorithm using Python."""

import numpy as np
# Example: minimize f(x) = x^2)
def objective_function(x):
    return x**2
def clonal_selection_algorithm(population_size, num_clones, mutation_rate, num_generations, search_space):
    # Initialize population
    population = np.random.uniform(search_space[0], search_space[1], population_size)
    
    for generation in range(num_generations):
        # Evaluate fitness
        fitness = np.array([objective_function(x) for x in population])
        
        # Select best antibodies
        sorted_indices = np.argsort(fitness)
        selected_antibodies = population[sorted_indices[:num_clones]]
        
        # Clone and mutate
        clones = np.repeat(selected_antibodies, num_clones)
        mutations = np.random.normal(0, mutation_rate, clones.shape)
        clones = clones + mutations
        clones = np.clip(clones, search_space[0], search_space[1])  # Ensure clones stay within search space
        
        # Replace population
        population = np.concatenate((clones, np.random.uniform(search_space[0], search_space[1], population_size - num_clones)))
        
        # Track best solution
        best_fitness = np.min(fitness)
        best_solution = population[np.argmin(fitness)]
        print(f"Generation {generation + 1}: Best Fitness = {best_fitness}, Best Solution = {best_solution}")
    
    return best_solution, best_fitness
    # Parameters
population_size = 20
num_clones = 5
mutation_rate = 0.1
num_generations = 50
search_space = (-10, 10)  # Define the search space for x
best_solution, best_fitness = clonal_selection_algorithm(population_size, num_clones, mutation_rate, num_generations, search_space)
print("\nFinal Result:")
print(f"Best Solution: {best_solution}")
print(f"Best Fitness: {best_fitness}")
# Out:
# Generation 1: Best Fitness = 0.005752872432978319, Best Solution = -0.02543799697443524
# Generation 2: Best Fitness = 1.0604228293778823e-06, Best Solution = -0.0066297370479178296
# Generation 3: Best Fitness = 1.4339659317933868e-05, Best Solution = 0.07018540085255963
# Generation 4: Best Fitness = 2.6148879229160964e-06, Best Solution = -0.06804970714962214
# Generation 5: Best Fitness = 3.7202474897336713e-06, Best Solution = -0.04239581594739272
# Generation 6: Best Fitness = 6.962326970640967e-07, Best Solution = -0.0769910765017528
# Generation 7: Best Fitness = 5.0495238484289164e-05, Best Solution = 0.1535044488774589
# Generation 8: Best Fitness = 1.2645162427082103e-05, Best Solution = -0.038151945263595534
# Generation 9: Best Fitness = 4.457515931190243e-05, Best Solution = -0.05685429058513018
# Generation 10: Best Fitness = 0.0002291427192004816, Best Solution = -0.007352597162060787
# Generation 11: Best Fitness = 1.3612107414550542e-05, Best Solution = 0.10760748658227288
# Generation 12: Best Fitness = 1.1505349716468684e-05, Best Solution = -0.1319420796379175
# Generation 13: Best Fitness = 6.669387215186535e-06, Best Solution = 0.2150559313276118
# Generation 14: Best Fitness = 0.00014392113571216997, Best Solution = -0.1337732423673944
# Generation 15: Best Fitness = 1.7346810430898842e-05, Best Solution = -0.03409779504166334
# Generation 16: Best Fitness = 4.449567093691066e-07, Best Solution = -0.16899148719295592
# Generation 17: Best Fitness = 0.0005335529872926176, Best Solution = -0.22881605122065407

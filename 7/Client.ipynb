# %%
import xmlrpc.client
server = xmlrpc.client.ServerProxy("http://localhost:1233")

a = input("Enter a string: ")
b = input("Enter another string: ")

c = server.concat(a, b)

print("Concatenated:", c)
# Out:
# Concatenated: Hello..!How are you
